    # Access orbit parameters (in ecliptic coordinates)
    coords = orbits.coordinates
    print("State vector at epoch:")
    print(f"Position (AU): {coords.x[0]}, {coords.y[0]}, {coords.z[0]}")
    print(f"Velocity (AU/day): {coords.vx[0]}, {coords.vy[0]}, {coords.vz[0]}")

else:
    print(f"Orbit determination failed: {error}")
# Out:
# Successfully determined 1 orbit(s)
# Number of rejected observations: 29
# State vector at epoch:
# Position (AU): -0.13519493393846008, 1.6022766081134305, -1.1454172089539092
# Velocity (AU/day): 0.0021024034146465784, -0.013888316886375651, 0.010018535335699172

# %%
print(orbits, "\n\n", rejected_observations)
# Out:
# Orbits(size=1)
#
#  ADESObservations(size=29)

# %%
print(len(obs_data_mpes), "\nfraction rejected:", len(rejected_observations)/len(obs_data_mpes))
print(type(rejected_observations))
print(dir(rejected_observations))     # Prints what all operations can be performed; Repeat this statement for variable named orbits as well
# Out:
# 11013
# fraction rejected: 0.00263325161173159
# <class 'adam_core.observations.ades.ADESObservations'>
# ...

# %%
rej_df = rejected_observations.to_dataframe()
rej_df['stn'].value_counts()
# Out:
# stn
# 323    5
# A77    3
# Y68    3
# E86    3
# E41    3
# E94    3
# 349    2
# 213    2
# Q14    2
# J47    2
# P87    1
# Name: count, dtype: int64

# %%
# =========================================
# WORKING orbital elements extraction
# =========================================

import numpy as np

if error is None:

    coords = orbits.coordinates

    # Extract values safely from PyArrow
    r = np.array([
        coords.x[0].as_py(),
        coords.y[0].as_py(),
        coords.z[0].as_py()
    ], dtype=float)

    v = np.array([
        coords.vx[0].as_py(),
        coords.vy[0].as_py(),
        coords.vz[0].as_py()
    ], dtype=float)

    # Solar gravitational parameter (AU^3/day^2)
    mu = 0.00029591220828559104

    r_norm = np.linalg.norm(r)
    v_norm = np.linalg.norm(v)

    # Angular momentum
    h = np.cross(r, v)
    h_norm = np.linalg.norm(h)

    # Inclination
    inc = np.degrees(np.arccos(h[2]/h_norm))

    # Node vector
    k = np.array([0.0,0.0,1.0])
    n = np.cross(k, h)
    n_norm = np.linalg.norm(n)

    # Eccentricity vector
    e_vec = (np.cross(v, h)/mu) - (r/r_norm)
    e = np.linalg.norm(e_vec)

    # Semi-major axis
    a = 1 / ((2/r_norm) - (v_norm**2/mu))

    # Longitude of ascending node
    Omega = np.degrees(np.arccos(n[0]/n_norm))
    if n[1] < 0:
        Omega = 360 - Omega

    # Argument of perihelion
    omega = np.degrees(np.arccos(np.dot(n, e_vec)/(n_norm*e)))
    if e_vec[2] < 0:
        omega = 360 - omega

    # True anomaly
    nu = np.degrees(np.arccos(np.dot(e_vec, r)/(e*r_norm)))
    if np.dot(r, v) < 0:
        nu = 360 - nu

    # Perihelion distance
    q = a * (1 - e)

    print("\n===== ORBITAL ELEMENTS =====\n")
    print("Semi-major axis a (AU):", a)
    print("Perihelion distance q (AU):", q)
    print("Eccentricity e:", e)
    print("Inclination i (deg):", inc)
    print("Longitude of Ascending Node Ω (deg):", Omega)
    print("Argument of Perihelion ω (deg):", omega)
    print("True anomaly ν (deg):", nu)

    print("\n===== OBSERVATION STATS =====")
    print("Rejected observations:", len(rejected_observations))
# Out:
# ===== ORBITAL ELEMENTS =====
#
# Semi-major axis a (AU): 140.93231986225405
# Perihelion distance q (AU): 0.005667688028273818
# Eccentricity e: 0.999959784327443
# Inclination i (deg): 144.4994584974208
# Longitude of Ascending Node Ω (deg): 7.811330814636382
# Argument of Perihelion ω (deg): 86.31228543120075
# True anomaly ν (deg): 186.121281180076
#
# ===== OBSERVATION STATS =====
# Rejected observations: 29

# %%
# =========================================
# MPC STYLE OUTPUT FORMAT
# (Formatting only — no recalculation)
# =========================================

import numpy as np
from datetime import datetime

# ---- 1. Compute Epoch from observation data ----

dates = []

for line in obs_data_mpes.split("\n"):
    parts = line.split()
    if len(parts) > 3:
        try:
            year = int(parts[1][1:5])
            month = int(parts[2])
            day_frac = float(parts[3])

            day = int(day_frac)
            frac = day_frac - day

            dt = datetime(year, month, day)
            # This formula for JD is for a specific epoch, it might be more accurate to use astropy.time.Time
            # However, since the original code uses it, I'll keep it for consistency.
            jd = 2440587.5 + dt.timestamp()/86400.0 + frac

            dates.append(jd)
        except:
            # Handle cases where parsing fails for a line
            pass

epoch_jd = np.mean(dates) if dates else None # Handle case where dates might be empty

# ---- 2. z parameter ----

z_param = 1.0 / a

# ---- 3. Convert angles to radians ----

i_rad = np.radians(inc)
Omega_rad = np.radians(Omega)
omega_rad = np.radians(omega)
nu_rad = np.radians(nu)

# ---- 4. True anomaly to eccentric anomaly ----

# For hyperbolic orbits (e > 1), the formula for E changes.
# Given e is very close to 1 (0.999959784327443), it's likely nearly parabolic.
# The current formula assumes elliptic orbit. Need to verify if this is correct for e very close to 1.
# Assuming it's still elliptic as e < 1.
E = 2*np.arctan(np.tan(nu_rad/2) * np.sqrt((1-e)/(1+e)))

# ---- 5. Mean anomaly ----

M = E - e*np.sin(E)

# ---- 6. Mean motion ----

mu = 0.00029591220828559104 # Re-defining mu for self-containment, though it's in kernel state.
n_mean = np.sqrt(mu/(abs(a**3)))

# ---- 7. Perihelion time ----

T_peri = epoch_jd - (M/n_mean)

# ---- 8. P and Q vectors ----

P = np.array([
    np.cos(Omega_rad)*np.cos(omega_rad) - np.sin(Omega_rad)*np.sin(omega_rad)*np.cos(i_rad),
    np.sin(Omega_rad)*np.cos(omega_rad) + np.cos(Omega_rad)*np.sin(omega_rad)*np.cos(i_rad),
    np.sin(omega_rad)*np.sin(i_rad)
])

Q = np.array([
    -np.cos(Omega_rad)*np.sin(omega_rad) - np.sin(Omega_rad)*np.cos(omega_rad)*np.cos(i_rad),
    -np.sin(Omega_rad)*np.sin(omega_rad) + np.cos(Omega_rad)*np.cos(omega_rad)*np.cos(i_rad),
    np.cos(omega_rad)*np.sin(i_rad)
])


print("\n\nOrbital elements:")
print("    C/2026 A1 (MAPS)")

# Epoch
if isinstance(epoch_jd, (float,int)):
    print(f"Epoch JD TT = {epoch_jd:.1f}")
else:
    print("Epoch JD TT = UNKNOWN")

# Perihelion time
if isinstance(T_peri, (float,int)):
    print(f"T (Perihelion JD TT) {T_peri:.5f}")
else:
    print("T (Perihelion JD TT) UNKNOWN")

print()

print(f"q   {q:.7f}            (2000.0)            P               Q")
print(f"z  {z_param:+.7f}      Peri.  {omega:9.5f}     {P[0]:+0.8f}     {Q[0]:+0.8f}")
print(f"                 Node   {Omega:9.5f}     {P[1]:+0.8f}     {Q[1]:+0.8f}")
print(f"e   {e:.7f}      Incl.  {inc:9.5f}     {P[2]:+0.8f}     {Q[2]:+0.8f}")

print("\nFrom observations, rejected:", len(rejected_observations))
# Out:
# Orbital elements:
#     C/2026 A1 (MAPS)
# Epoch JD TT = 2461068.0
# T (Perihelion JD TT) 2461144.47164
#
# q   0.0056677            (2000.0)            P               Q
# z  +0.0070956      Peri.   86.31229     +0.17413934     -0.98155300
#                  Node     7.81133     -0.79614426     -0.18750642
# e   0.9999598      Incl.  144.49946     +0.57950825     +0.03735034
#
# From observations, rejected: 29

# %%
# =========================================
# FINAL MPC PARAMETER BLOCK (CLEAN VERSION)
# =========================================

import numpy as np
from datetime import datetime

# ---- 1. Compute Epoch from observation data ----

dates = []

for line in obs_data_mpes.split("\n"):
    parts = line.split()
    if len(parts) > 3:
        try:
            year = int(parts[1][1:5])
            month = int(parts[2])
            day_frac = float(parts[3])

            day = int(day_frac)
            frac = day_frac - day

            dt = datetime(year, month, day)
            jd = 2440587.5 + dt.timestamp()/86400.0 + frac

            dates.append(jd)
        except:
            pass

epoch_jd = np.mean(dates)

# ---- 2. z parameter ----

z_param = 1.0 / a

# ---- 3. Convert angles to radians ----

i_rad = np.radians(inc)
Omega_rad = np.radians(Omega)
omega_rad = np.radians(omega)
nu_rad = np.radians(nu)

# ---- 4. True anomaly to eccentric anomaly ----

E = 2*np.arctan(np.tan(nu_rad/2) * np.sqrt((1-e)/(1+e)))

# ---- 5. Mean anomaly ----

M = E - e*np.sin(E)

# ---- 6. Mean motion ----

mu = 0.00029591220828559104
n_mean = np.sqrt(mu/(abs(a**3)))

# ---- 7. Perihelion time ----

T_peri = epoch_jd - (M/n_mean)

# ---- 8. P and Q vectors ----

P = np.array([
    np.cos(Omega_rad)*np.cos(omega_rad) - np.sin(Omega_rad)*np.sin(omega_rad)*np.cos(i_rad),
    np.sin(Omega_rad)*np.cos(omega_rad) + np.cos(Omega_rad)*np.sin(omega_rad)*np.cos(i_rad),
    np.sin(omega_rad)*np.sin(i_rad)
])

Q = np.array([
    -np.cos(Omega_rad)*np.sin(omega_rad) - np.sin(Omega_rad)*np.cos(omega_rad)*np.cos(i_rad),
    -np.sin(Omega_rad)*np.sin(omega_rad) + np.cos(Omega_rad)*np.cos(omega_rad)*np.cos(i_rad),
    np.cos(omega_rad)*np.sin(i_rad)
])

print("Epoch (JD):", epoch_jd)
print("Perihelion time T (JD):", T_peri)
print("Perihelion distance q:", q)
print("Eccentricity e:", e)
print("Inclination (deg):", inc)
print("Longitude of ascending node (deg):", Omega)
print("Argument of perihelion (deg):", omega)
print("z parameter:", z_param)
print("P vector:", P)
print("Q vector:", Q)
# Out:
# Epoch (JD): 2461067.96735
# Perihelion time T (JD): 2461144.471644446
# Perihelion distance q: 0.005667688028273818
# Eccentricity e: 0.999959784327443
# Inclination (deg): 144.4994584974208
# Longitude of ascending node (deg): 7.811330814636382
# Argument of perihelion (deg): 86.31228543120075
# z parameter: 0.0070956044786418815
# P vector: [ 0.17413934 -0.79614426  0.57950825]
# Q vector: [-0.981553   -0.18750642  0.03735034]
